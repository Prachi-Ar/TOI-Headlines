# %% [markdown]
# <a href="https://colab.research.google.com/github/prachiarya0067/POLS8038ANU/blob/master/Institutionsassignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
# !pip install beautifulsoup4

# %%
# !pip install requirements
# Out:
# ERROR: Could not find a version that satisfies the requirement requirements (from versions: none)
# ERROR: No matching distribution found for requirements

# %%
from bs4 import BeautifulSoup
import requests
import datetime
import pandas as pd
import re

# %%
#BJP Modi India May October
p = re.compile('.*Modi.*')# Regex to match the word "trump" in the link
q = re.compile('.*BJP.*')         


#May 2018
time=43221
finalistBf=[]

for i in range (1, 32):
  
  #url1=https://timesofindia.indiatimes.com/2018/5/1/archivelist/year-2018,month-5,starttime-43221.cms
  part1="https://timesofindia.indiatimes.com/2018/5/"
  part2="/archivelist/year-2018,month-5,starttime-"
  url = part1+str(i)+part2+str(time)+".cms" # Link to CNN's SiteMap
  time=time+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBf.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#June  2018
#url = https://timesofindia.indiatimes.com/2018/6/1/archivelist/year-2018,month-6,starttime-43252.cms
timej = 43252
for i in range (1, 31):

  part1="https://timesofindia.indiatimes.com/2018/6/"
  part2="/archivelist/year-2018,month-6,starttime-"
  url = part1+str(i)+part2+str(timej)+".cms" # Link to CNN's SiteMap
  timej=timej+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBf.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#July 
#url = https://timesofindia.indiatimes.com/2018/7/1/archivelist/year-2018,month-7,starttime-43282.cms

timejl = 43282
for i in range (1, 32):

  part1="https://timesofindia.indiatimes.com/2018/7/"
  part2="/archivelist/year-2018,month-7,starttime-"
  url = part1+str(i)+part2+str(timejl)+".cms" # Link to CNN's SiteMap
  timejl=timejl+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBf.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#August
#url = https://timesofindia.indiatimes.com/2018/8/1/archivelist/year-2018,month-8,starttime-43313.cms

timeau = 43313
for i in range (1, 32):

  part1="https://timesofindia.indiatimes.com/2018/8/"
  part2="/archivelist/year-2018,month-8,starttime-"
  url = part1+str(i)+part2+str(timeau)+".cms" # Link to CNN's SiteMap
  timeau=timeau+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBf.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#September
#url = https://timesofindia.indiatimes.com/2018/9/1/archivelist/year-2018,month-9,starttime-43344.cms
timesp = 43344

for i in range (1, 31):

  part1="https://timesofindia.indiatimes.com/2018/9/"
  part2="/archivelist/year-2018,month-9,starttime-"
  url = part1+str(i)+part2+str(timesp)+".cms" # Link to CNN's SiteMap
  timesp=timesp+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBf.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#October
#url = https://timesofindia.indiatimes.com/2018/10/1/archivelist/year-2018,month-10,starttime-43374.cms
timeoc = 43374

for i in range (1, 32):

  part1="https://timesofindia.indiatimes.com/2018/10/"
  part2="/archivelist/year-2018,month-10,starttime-"
  url = part1+str(i)+part2+str(timeoc)+".cms" # Link to CNN's SiteMap
  timeoc=timeoc+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBf.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

# %%
#BJP India November April
#November 
#url = https://timesofindia.indiatimes.com/2018/11/1/archivelist/year-2018,month-11,starttime-43405.cms

timenv = 43405

for i in range (1, 31):

  part1="https://timesofindia.indiatimes.com/2018/11/"
  part2="/archivelist/year-2018,month-11,starttime-"
  url = part1+str(i)+part2+str(timenv)+".cms" # Link to CNN's SiteMap
  timenv=timenv+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBf.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#December 
#url = https://timesofindia.indiatimes.com/2018/12/1/archivelist/year-2018,month-12,starttime-43435.cms

timedc = 43435

for i in range (1, 32):

  part1="https://timesofindia.indiatimes.com/2018/12/"
  part2="/archivelist/year-2018,month-12,starttime-"
  url = part1+str(i)+part2+str(timedc)+".cms" # Link to CNN's SiteMap
  timedc=timedc+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBf.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#January
#url = https://timesofindia.indiatimes.com/2019/1/1/archivelist/year-2019,month-1,starttime-43466.cms

timejn = 43466

for i in range (1, 32):

  part1="https://timesofindia.indiatimes.com/2019/1/"
  part2="/archivelist/year-2019,month-1,starttime-"
  url = part1+str(i)+part2+str(timejn)+".cms" # Link to CNN's SiteMap
  timejn=timejn+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBf.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#February
#url = https://timesofindia.indiatimes.com/2019/2/1/archivelist/year-2019,month-2,starttime-43497.cms

timefb = 43497

for i in range (1, 29):

  part1="https://timesofindia.indiatimes.com/2019/2/"
  part2="/archivelist/year-2019,month-2,starttime-"
  url = part1+str(i)+part2+str(timefb)+".cms" # Link to CNN's SiteMap
  timefb=timefb+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBf.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#March
#url = https://timesofindia.indiatimes.com/2019/3/1/archivelist/year-2019,month-3,starttime-43525.cms

timemr = 43525

for i in range (1, 32):

  part1="https://timesofindia.indiatimes.com/2019/3/"
  part2="/archivelist/year-2019,month-3,starttime-"
  url = part1+str(i)+part2+str(timemr)+".cms" # Link to CNN's SiteMap
  timemr=timemr+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBf.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#April
#url = https://timesofindia.indiatimes.com/2019/4/1/archivelist/year-2019,month-4,starttime-43556.cms

timeap = 43556

for i in range (1, 31):

  part1="https://timesofindia.indiatimes.com/2020/4/"
  part2="/archivelist/year-2020,month-4,starttime-"
  url = part1+str(i)+part2+str(timeap)+".cms" # Link to CNN's SiteMap
  timeap=timeap+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBf.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

# %%
df = pd.DataFrame(finalistBf)
df
# Out:
#                                                      0  ...    69
# 0    In poll mode, BJP to implement its promises in...  ...  None
# 1    PM Modi shows solidarity with Gowda ahead of K...  ...  None
# 2    CM Chouhan meets PM Modi, discusses trade scop...  ...  None
# 3    No vacancy for alliance of non-BJP parties: Pa...  ...  None
# 4    Raghuramkrishna quits BJP, joins TDP in CM’s p...  ...  None
# ..                                                 ...  ...   ...
# 360  Meet Rahul Gandhi Bhopali & Narendra Modi paan...  ...  None
# 361  PM Modi fires back at opposition, forcefully d...  ...  None
# 362  Intermediate results: Telangana BJP wants judi...  ...  None
# 363  The makers of PM Modi’s biopic seek clarity fr...  ...  None
# 364  EC may consider poll code complaints against P...  ...  None
#
# [365 rows x 70 columns]

# %%
finalistBf
# Out:
# [['In poll mode, BJP to implement its promises in next 2 months',
#   'BJP ropes in Shivraj, Gehlot for campaigning in Karnataka',
#   'AlinaSaldanha , Aldona BJP threaten to sue Goencho Avaaz',
#   'BJP accuses activist group of selective targeting',
#   'Olpad BJP MLA, supporters gherao irrigation office',
#   'Rajendra Trivedi calls Ambedkar, PM Modi ‘Brahmins’',
#   'BJP, Congress national chiefs go all out to conquer Karnataka',
#   'Nirmal’s replacement BJP’s signal to its base',
#   'No place for divisive thoughts: PM Modi',
#   'PM Narendra Modi wishes to visit Lahaul-Spiti via Rohtang tunnel: CM Jai Ram Thakur',
#   'Village of 96 families gets Modicare rolling',
#   'Lone RLD MLA joins BJP ahead of Kairana bypoll',
#   'Narendra Modi'],
#  ['PM Modi shows solidarity with Gowda ahead of Karnataka polls',
#   'BJP squirms as UP mantri says Jinnah was a ‘mahapurush’',
#   'Farm meet to help BJP reach out to SC/STs',
# ...

# %%
df = pd.DataFrame(finalistBf)
df
# Out:
#                                                      0  ...    69
# 0    In poll mode, BJP to implement its promises in...  ...  None
# 1    PM Modi shows solidarity with Gowda ahead of K...  ...  None
# 2    CM Chouhan meets PM Modi, discusses trade scop...  ...  None
# 3    No vacancy for alliance of non-BJP parties: Pa...  ...  None
# 4    Raghuramkrishna quits BJP, joins TDP in CM’s p...  ...  None
# ..                                                 ...  ...   ...
# 360  Meet Rahul Gandhi Bhopali & Narendra Modi paan...  ...  None
# 361  PM Modi fires back at opposition, forcefully d...  ...  None
# 362  Intermediate results: Telangana BJP wants judi...  ...  None
# 363  The makers of PM Modi’s biopic seek clarity fr...  ...  None
# 364  EC may consider poll code complaints against P...  ...  None
#
# [365 rows x 70 columns]

# %%
for i in df:
  for lines in df[i]:
    if lines is not None:
      lines = [re.sub(r'[^A-Za-z0-9]+', '', x) for x in lines]

lines

lines2 = []

#for word in lines:
    #if word != '':
        #lines2.append(word)

# %%
import numpy as np

all_sentences = []


for i in df:
  for word in df[i]:
    all_sentences.append(word)

dfsingledimen = pd.DataFrame(all_sentences)
dfsingledimen

#linesC
# Out:
#                                                        0
# 0      In poll mode, BJP to implement its promises in...
# 1      PM Modi shows solidarity with Gowda ahead of K...
# 2      CM Chouhan meets PM Modi, discusses trade scop...
# 3      No vacancy for alliance of non-BJP parties: Pa...
# 4      Raghuramkrishna quits BJP, joins TDP in CM’s p...
# ...                                                  ...
# 25545                                               None
# 25546                                               None
# 25547                                               None
# 25548                                               None
# 25549                                               None
#
# [25550 rows x 1 columns]

# %%
all_sentences_list = []

for i in range(0, len(dfsingledimen)):
    all_sentences_list.append(dfsingledimen[0][i])

all_sentences_list
#df1 = df.to_string()

#df_split = df1.split()
# Out:
# ['In poll mode, BJP to implement its promises in next 2 months',
#  'PM Modi shows solidarity with Gowda ahead of Karnataka polls',
#  'CM Chouhan meets PM Modi, discusses trade scope with UAE',
#  'No vacancy for alliance of non-BJP parties: Paswan on efforts to form broad coalition',
#  'Raghuramkrishna quits BJP, joins TDP in CM’s presence',
#  '‘CPI open for alliance with Congress to defeat BJP’',
#  'Left parties up ante against Modi government',
#  'CM Raje will lead next BJP govt, says Rajasthan in-charge',
#  'Patole pulls out; BJP’s Patle, NCP’s Kukade finalized',
#  'Clear stand on special category status demand: Tariq Anwar to BJP',
#  'BJP to hold workshop on Sunday',
#  'Congress unity no challenge for BJP, we will win elections: Mallaiya',
#  'Scindia tears into BJP netas over Kamal Nath’s age jibe',
#  'BJP using cops to hound Tharoor, says Congress',
#  'Will ask Dalits to not vote for BJP: Jignesh Mewani',
#  'First choice of nation is BJP, says Vasundhara Raje',
# ...

# %%
remove_none = []
for i in all_sentences_list:
  if i is not None:
    remove_none.append(i)

len(remove_none)
remove_none
# Out:
# ['In poll mode, BJP to implement its promises in next 2 months',
#  'PM Modi shows solidarity with Gowda ahead of Karnataka polls',
#  'CM Chouhan meets PM Modi, discusses trade scope with UAE',
#  'No vacancy for alliance of non-BJP parties: Paswan on efforts to form broad coalition',
#  'Raghuramkrishna quits BJP, joins TDP in CM’s presence',
#  '‘CPI open for alliance with Congress to defeat BJP’',
#  'Left parties up ante against Modi government',
#  'CM Raje will lead next BJP govt, says Rajasthan in-charge',
#  'Patole pulls out; BJP’s Patle, NCP’s Kukade finalized',
#  'Clear stand on special category status demand: Tariq Anwar to BJP',
#  'BJP to hold workshop on Sunday',
#  'Congress unity no challenge for BJP, we will win elections: Mallaiya',
#  'Scindia tears into BJP netas over Kamal Nath’s age jibe',
#  'BJP using cops to hound Tharoor, says Congress',
#  'Will ask Dalits to not vote for BJP: Jignesh Mewani',
#  'First choice of nation is BJP, says Vasundhara Raje',
# ...

# %%
#df_split
lines = list()
for line in all_sentences_list:
  if line is not None:
    words = line.split()
    lines.append(words)


print(lines)
# Out:
# [['In', 'poll', 'mode,', 'BJP', 'to', 'implement', 'its', 'promises', 'in', 'next', '2', 'months'], ['PM', 'Modi', 'shows', 'solidarity', 'with', 'Gowda', 'ahead', 'of', 'Karnataka', 'polls'], ['CM', 'Chouhan', 'meets', 'PM', 'Modi,', 'discusses', 'trade', 'scope', 'with', 'UAE'], ['No', 'vacancy', 'for', 'alliance', 'of', 'non-BJP', 'parties:', 'Paswan', 'on', 'efforts', 'to', 'form', 'broad', 'coalition'], ['Raghuramkrishna', 'quits', 'BJP,', 'joins', 'TDP', 'in', 'CM’s', 'presence'], ['‘CPI', 'open', 'for', 'alliance', 'with', 'Congress', 'to', 'defeat', 'BJP’'], ['Left', 'parties', 'up', 'ante', 'against', 'Modi', 'government'], ['CM', 'Raje', 'will', 'lead', 'next', 'BJP', 'govt,', 'says', 'Rajasthan', 'in-charge'], ['Patole', 'pulls', 'out;', 'BJP’s', 'Patle,', 'NCP’s', 'Kukade', 'finalized'], ['Clear', 'stand', 'on', 'special', 'category', 'status', 'demand:', 'Tariq', 'Anwar', 'to', 'BJP'], ['BJP', 'to', 'hold', 'workshop', 'on', 'Sunday'], ['Congress', 'unity', 'no', 'challe
# ...

# %%
all_words_list = []

for i in lines:
    for j in i:
      all_words_list.append(j)

all_words_list
# Out:
# ['In',
#  'poll',
#  'mode,',
#  'BJP',
#  'to',
#  'implement',
#  'its',
#  'promises',
#  'in',
#  'next',
#  '2',
#  'months',
#  'PM',
#  'Modi',
#  'shows',
#  'solidarity',
#  'with',
#  'Gowda',
#  'ahead',
#  'of',
#  'Karnataka',
#  'polls',
#  'CM',
#  'Chouhan',
#  'meets',
#  'PM',
#  'Modi,',
#  'discusses',
#  'trade',
#  'scope',
#  'with',
#  'UAE',
#  'No',
#  'vacancy',
#  'for',
#  'alliance',
#  'of',
#  'non-BJP',
#  'parties:',
#  'Paswan',
#  'on',
#  'efforts',
#  'to',
#  'form',
#  'broad',
#  'coalition',
#  'Raghuramkrishna',
#  'quits',
#  'BJP,',
#  'joins',
#  'TDP',
#  'in',
#  'CM’s',
#  'presence',
#  '‘CPI',
#  'open',
#  'for',
#  'alliance',
#  'with',
#  'Congress',
#  'to',
#  'defeat',
#  'BJP’',
#  'Left',
#  'parties',
#  'up',
#  'ante',
#  'against',
#  'Modi',
#  'government',
#  'CM',
#  'Raje',
#  'will',
#  'lead',
#  'next',
#  'BJP',
#  'govt,',
#  'says',
#  'Rajasthan',
#  'in-charge',
#  'Patole',
#  'pulls',
#  'out;',
# ...

# %%
all_words_list = [re.sub(r'[^A-Za-z0-9]+', '', x) for x in all_words_list]

all_words_list

lines2 = []

for word in all_words_list:
    if word != '':
        lines2.append(word)

# %%
#This is stemming the words to their root
from nltk.stem.snowball import SnowballStemmer

# The Snowball Stemmer requires that you pass a language parameter
s_stemmer = SnowballStemmer(language='english')

stem = []
for word in lines2:
    stem.append(s_stemmer.stem(word))
    
stem
# Out:
# ['in',
#  'poll',
#  'mode',
#  'bjp',
#  'to',
#  'implement',
#  'it',
#  'promis',
#  'in',
#  'next',
#  '2',
#  'month',
#  'pm',
#  'modi',
#  'show',
#  'solidar',
#  'with',
#  'gowda',
#  'ahead',
#  'of',
#  'karnataka',
#  'poll',
#  'cm',
#  'chouhan',
#  'meet',
#  'pm',
#  'modi',
#  'discuss',
#  'trade',
#  'scope',
#  'with',
#  'uae',
#  'no',
#  'vacanc',
#  'for',
#  'allianc',
#  'of',
#  'nonbjp',
#  'parti',
#  'paswan',
#  'on',
#  'effort',
#  'to',
#  'form',
#  'broad',
#  'coalit',
#  'raghuramkrishna',
#  'quit',
#  'bjp',
#  'join',
#  'tdp',
#  'in',
#  'cms',
#  'presenc',
#  'cpi',
#  'open',
#  'for',
#  'allianc',
#  'with',
#  'congress',
#  'to',
#  'defeat',
#  'bjp',
#  'left',
#  'parti',
#  'up',
#  'ant',
#  'against',
#  'modi',
#  'govern',
#  'cm',
#  'raje',
#  'will',
#  'lead',
#  'next',
#  'bjp',
#  'govt',
#  'say',
#  'rajasthan',
#  'incharg',
#  'patol',
#  'pull',
#  'out',
#  'bjps',
#  'patl',
#  'ncps',
#  'kukad',
# ...

# %%
stem2 = []

for word in stem:
    if word not in nlp.Defaults.stop_words:
        stem2.append(word)

stem2
# Out:
# ['poll',
#  'mode',
#  'bjp',
#  'implement',
#  'promis',
#  '2',
#  'month',
#  'pm',
#  'modi',
#  'solidar',
#  'gowda',
#  'ahead',
#  'karnataka',
#  'poll',
#  'cm',
#  'chouhan',
#  'meet',
#  'pm',
#  'modi',
#  'discuss',
#  'trade',
#  'scope',
#  'uae',
#  'vacanc',
#  'allianc',
#  'nonbjp',
#  'parti',
#  'paswan',
#  'effort',
#  'form',
#  'broad',
#  'coalit',
#  'raghuramkrishna',
#  'quit',
#  'bjp',
#  'join',
#  'tdp',
#  'cms',
#  'presenc',
#  'cpi',
#  'open',
#  'allianc',
#  'congress',
#  'defeat',
#  'bjp',
#  'left',
#  'parti',
#  'ant',
#  'modi',
#  'govern',
#  'cm',
#  'raje',
#  'lead',
#  'bjp',
#  'govt',
#  'rajasthan',
#  'incharg',
#  'patol',
#  'pull',
#  'bjps',
#  'patl',
#  'ncps',
#  'kukad',
#  'final',
#  'clear',
#  'stand',
#  'special',
#  'categori',
#  'status',
#  'demand',
#  'tariq',
#  'anwar',
#  'bjp',
#  'bjp',
#  'hold',
#  'workshop',
#  'sunday',
#  'congress',
#  'uniti',
#  'challeng',
#  'bjp',
#  'win',
#  'elect',
# ...

# %%
dfB = pd.DataFrame(stem2)

dfB = dfB[0].value_counts()

dfB
# Out:
# bjp           3503
# modi          2197
# pm             954
# narendra       842
# congress       658
#               ...
# remot            1
# gutka            1
# pound            1
# motormouth       1
# gsm              1
# Name: 0, Length: 6094, dtype: int64

# %%
dfB = dfB[:20,]
plt.figure(figsize=(10,5))
sns.barplot(dfB.values, dfB.index, alpha=0.8)
plt.title('Top Words Overall: BJP & Modi')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()

# %%
def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(ent.text + ' - ' + ent.label_ + ' - ' + str(spacy.explain(ent.label_)))
str1 = " " 
stem2 = str1.join(lines2)

stem2 = nlp(stem2)

label = [(X.text, X.label_) for X in stem2.ents]

df6 = pd.DataFrame(label, columns = ['Word','Entity'])

df7 = df6.where(df6['Entity'] == 'ORG')

df7 = df7['Word'].value_counts()

df = df7[:10,]
plt.figure(figsize=(10,5))
sns.barplot(df.values, df.index, alpha=1)
plt.title('Top Organizations Mentioned: BJP & Modi')
plt.ylabel('Word from Tweet', fontsize=14)
plt.xlabel('Count of Words', fontsize=14)
plt.show()

# %%
dfB_
# Out:
#                                                       0  ...  Analysis
# 0     In poll mode, BJP to implement its promises in...  ...   Neutral
# 1     PM Modi shows solidarity with Gowda ahead of K...  ...   Neutral
# 2     CM Chouhan meets PM Modi, discusses trade scop...  ...   Neutral
# 3     No vacancy for alliance of non-BJP parties: Pa...  ...  Positive
# 4     Raghuramkrishna quits BJP, joins TDP in CM’s p...  ...   Neutral
# ...                                                 ...  ...       ...
# 6056        In west Delhi, AAP attacks BJP and Congress  ...   Neutral
# 6057  It's official: BJP fields Surendran in Pathana...  ...   Neutral
# 6058  Lok Sabha elections: BJP approves names of can...  ...   Neutral
# 6059  Lok Sabha elections: BJP approves names of can...  ...   Neutral
# 6060                                      Narendra Modi  ...   Neutral
#
# [6061 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
#import twitterscraper as ts
from wordcloud import WordCloud
from textblob import TextBlob
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.rc('xtick', labelsize=5)
dfB_ = pd.DataFrame(remove_none)
# ## To create subjectivity (use to tell how subjective or opinionated the tweet is
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity
#
# ## To create polarity (use to tell how positive or negative the tweet is)
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# ## Create the Subjectivity and Polarity results columns in the df
dfB_["Subjectivity"] = dfB_[0].apply(getSubjectivity)
dfB_["Polarity"] = dfB_[0].apply(getPolarity)

def getAnalysis(score):
    if score < 0:
        return "Negative"
    elif score == 0:
        return "Neutral"
    else :
        return "Positive"
#
dfB_["Analysis"] = dfB_["Polarity"].apply(getAnalysis)

pheadlines = dfB_[dfB_.Analysis == "Positive"]
percentage_positive = pheadlines.shape[0] / dfB_.shape[0]
print(percentage_positive)

nheadlines = dfB_[dfB_.Analysis == "Negative"]
percentage_negative = nheadlines.shape[0] / dfB_.shape[0]
print(percentage_negative)
# Out:
# 0.13941593796403234
# 0.08694934829236099

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots()

positive = 13.94
negative = 8.69
neutral = 77.37

ax.broken_barh([(0, positive), (positive, positive+negative), (positive+negative, positive+negative+neutral)], [20, 1], facecolors=('greenyellow', 'coral', 'gainsboro'))
ax.set_ylim(1, 5)
ax.set_xlim(0, 100)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_yticks([15, 25])
ax.set_xticks([0, 25, 50, 75, 100])

ax.set_axisbelow(True) 

ax.set_yticklabels(['Q1'])
ax.grid(axis='x')
ax.text(positive-6, 19, "13.94%", fontsize=8)
ax.text((positive+negative)-4, 19, "8.69%", fontsize=8)
ax.text((positive+negative+neutral)+0, 19, "77.37%", fontsize=8)

fig.suptitle('Sentiment Analysis: BJP and Modi', fontsize=16)

leg1 = mpatches.Patch(color='greenyellow', label='Positive')
leg2 = mpatches.Patch(color='coral', label='Negative')
leg3 = mpatches.Patch(color='gainsboro', label='Neutral')
ax.legend(handles=[leg1, leg2, leg3], ncol=3)

plt.show()

# %%
#Congress Rahul Gandhi India May October
p = re.compile('.*Rahul Gandhi.*')# Regex to match the word "trump" in the link
q = re.compile('.*Congress.*')         


#May 2018
time=43221
finalistBfC=[]

for i in range (1, 32):
  
  #url1=https://timesofindia.indiatimes.com/2018/5/1/archivelist/year-2018,month-5,starttime-43221.cms
  part1="https://timesofindia.indiatimes.com/2018/5/"
  part2="/archivelist/year-2018,month-5,starttime-"
  url = part1+str(i)+part2+str(time)+".cms" # Link to CNN's SiteMap
  time=time+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBfC.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#June  2018
#url = https://timesofindia.indiatimes.com/2018/6/1/archivelist/year-2018,month-6,starttime-43252.cms
timej = 43252
for i in range (1, 31):

  part1="https://timesofindia.indiatimes.com/2018/6/"
  part2="/archivelist/year-2018,month-6,starttime-"
  url = part1+str(i)+part2+str(timej)+".cms" # Link to CNN's SiteMap
  timej=timej+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBfC.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#July 
#url = https://timesofindia.indiatimes.com/2018/7/1/archivelist/year-2018,month-7,starttime-43282.cms

timejl = 43282
for i in range (1, 32):

  part1="https://timesofindia.indiatimes.com/2018/7/"
  part2="/archivelist/year-2018,month-7,starttime-"
  url = part1+str(i)+part2+str(timejl)+".cms" # Link to CNN's SiteMap
  timejl=timejl+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBfC.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#August
#url = https://timesofindia.indiatimes.com/2018/8/1/archivelist/year-2018,month-8,starttime-43313.cms

timeau = 43313
for i in range (1, 32):

  part1="https://timesofindia.indiatimes.com/2018/8/"
  part2="/archivelist/year-2018,month-8,starttime-"
  url = part1+str(i)+part2+str(timeau)+".cms" # Link to CNN's SiteMap
  timeau=timeau+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBfC.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#September
#url = https://timesofindia.indiatimes.com/2018/9/1/archivelist/year-2018,month-9,starttime-43344.cms
timesp = 43344

for i in range (1, 31):

  part1="https://timesofindia.indiatimes.com/2018/9/"
  part2="/archivelist/year-2018,month-9,starttime-"
  url = part1+str(i)+part2+str(timesp)+".cms" # Link to CNN's SiteMap
  timesp=timesp+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBfC.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#October
#url = https://timesofindia.indiatimes.com/2018/10/1/archivelist/year-2018,month-10,starttime-43374.cms
timeoc = 43374

for i in range (1, 32):

  part1="https://timesofindia.indiatimes.com/2018/10/"
  part2="/archivelist/year-2018,month-10,starttime-"
  url = part1+str(i)+part2+str(timeoc)+".cms" # Link to CNN's SiteMap
  timeoc=timeoc+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBfC.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

# %%
#Congress Rahul Gandhi November April
#November 
#url = https://timesofindia.indiatimes.com/2018/11/1/archivelist/year-2018,month-11,starttime-43405.cms

timenv = 43405

for i in range (1, 31):

  part1="https://timesofindia.indiatimes.com/2018/11/"
  part2="/archivelist/year-2018,month-11,starttime-"
  url = part1+str(i)+part2+str(timenv)+".cms" # Link to CNN's SiteMap
  timenv=timenv+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBfC.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#December 
#url = https://timesofindia.indiatimes.com/2018/12/1/archivelist/year-2018,month-12,starttime-43435.cms

timedc = 43435

for i in range (1, 32):

  part1="https://timesofindia.indiatimes.com/2018/12/"
  part2="/archivelist/year-2018,month-12,starttime-"
  url = part1+str(i)+part2+str(timedc)+".cms" # Link to CNN's SiteMap
  timedc=timedc+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBfC.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#January
#url = https://timesofindia.indiatimes.com/2019/1/1/archivelist/year-2019,month-1,starttime-43466.cms

timejn = 43466

for i in range (1, 32):

  part1="https://timesofindia.indiatimes.com/2019/1/"
  part2="/archivelist/year-2019,month-1,starttime-"
  url = part1+str(i)+part2+str(timejn)+".cms" # Link to CNN's SiteMap
  timejn=timejn+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBfC.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#February
#url = https://timesofindia.indiatimes.com/2019/2/1/archivelist/year-2019,month-2,starttime-43497.cms

timefb = 43497

for i in range (1, 29):

  part1="https://timesofindia.indiatimes.com/2019/2/"
  part2="/archivelist/year-2019,month-2,starttime-"
  url = part1+str(i)+part2+str(timefb)+".cms" # Link to CNN's SiteMap
  timefb=timefb+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBfC.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#March
#url = https://timesofindia.indiatimes.com/2019/3/1/archivelist/year-2019,month-3,starttime-43525.cms

timemr = 43525

for i in range (1, 32):

  part1="https://timesofindia.indiatimes.com/2019/3/"
  part2="/archivelist/year-2019,month-3,starttime-"
  url = part1+str(i)+part2+str(timemr)+".cms" # Link to CNN's SiteMap
  timemr=timemr+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBfC.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

#April
#url = https://timesofindia.indiatimes.com/2019/4/1/archivelist/year-2019,month-4,starttime-43556.cms

timeap = 43556

for i in range (1, 31):

  part1="https://timesofindia.indiatimes.com/2020/4/"
  part2="/archivelist/year-2020,month-4,starttime-"
  url = part1+str(i)+part2+str(timeap)+".cms" # Link to CNN's SiteMap
  timeap=timeap+1
  #print(url)
  r = requests.get(url)
  data = r.text
  soup = BeautifulSoup(data, "html")
  finalistBfC.append([x.text for x in soup.findAll("a") if p.match(x.text) or q.match(x.text)])

# %%
dfC = pd.DataFrame(finalistBfC)
dfC
# Out:
#                                                      0  ...    42
# 0    Discontent over cabinet expansion continues in...  ...  None
# 1    Lingayat move will not save Congress from vote...  ...  None
# 2    CPM, Congress join hands to take on TMC in Ben...  ...  None
# 3    Azad seeking votes on communal lines, says BJP...  ...  None
# 4    You can defeat Rajas, Maharajas of Congress: A...  ...  None
# ..                                                 ...  ...   ...
# 360  Meet Rahul Gandhi Bhopali & Narendra Modi paan...  ...  None
# 361  Congress fighting 2019 polls on 1971 agenda: A...  ...  None
# 362  TRS taking credit for Congress regime achievem...  ...  None
# 363  Why government not directing RBI to give loan ...  ...  None
# 364           Congress alleges double voting in Idukki  ...  None
#
# [365 rows x 43 columns]

# %%
dfC[1]
# Out:
# 0                Senior Congress leader Iqbal Patel dies
# 1      Karnataka election 2018: Congress achievements...
# 2      Congress hits out at govt over failure to curb...
# 3           Congress, NCP join hands again for 3 bypolls
# 4          Congress holds ‘matka phod’ protest in Jaipur
#                              ...
# 360    Local Congress a divided house on eve of Rahul...
# 361    Debar CM Arvind Kejriwal for ‘communal’ call: ...
# 362    Congress may go to court against PM Modi, Amit...
# 363    Sidelined, BJP ex-MLA Jitendra Daga joins Cong...
# 364    Rahul Gandhi to address three campaign meeting...
# Name: 1, Length: 365, dtype: object

# %%
for i in dfC:
  for lines in dfC[i]:
    if lines is not None:
      lines = [re.sub(r'[^A-Za-z0-9]+', '', x) for x in lines]

lines

lines2 = []

#for word in lines:
    #if word != '':
        #lines2.append(word)

# %%
import numpy as np

all_sentencesC = []


for i in dfC:
  for word in dfC[i]:
    all_sentencesC.append(word)

dfCsingledimen = pd.DataFrame(all_sentencesC)
dfCsingledimen

#linesC
# Out:
#                                                        0
# 0      Discontent over cabinet expansion continues in...
# 1      Lingayat move will not save Congress from vote...
# 2      CPM, Congress join hands to take on TMC in Ben...
# 3      Azad seeking votes on communal lines, says BJP...
# 4      You can defeat Rajas, Maharajas of Congress: A...
# ...                                                  ...
# 15690                                               None
# 15691                                               None
# 15692                                               None
# 15693                                               None
# 15694                                               None
#
# [15695 rows x 1 columns]

# %%
dfCsingledimen[0][15600]

# %%
all_sentences_list = []

for i in range(0, len(dfCsingledimen)):
    all_sentences_list.append(dfCsingledimen[0][i])

all_sentences_list
#df1 = df.to_string()

#df_split = df1.split()
# Out:
# ['Discontent over cabinet expansion continues in Congress',
#  'Lingayat move will not save Congress from voters’ anger, says Prakash Javadekar',
#  'CPM, Congress join hands to take on TMC in Bengal bypolls',
#  'Azad seeking votes on communal lines, says BJP; Congress neta denies claim',
#  'You can defeat Rajas, Maharajas of Congress: Amit Shah',
#  '‘CPI open for alliance with Congress to defeat BJP’',
#  "Congress MLA Aditi Singh denies wedding rumours with 'bro Rahul Gandhi'",
#  '2 arrested for murder of Congress ex-MLA’s cousin',
#  'Congress devises strategy to keep oust-CJI move ‘alive’',
#  'Congress MP flays govt over poor law and order',
#  'Congress keeps anti-PDA pot boiling, wants it scrapped',
#  'Congress unity no challenge for BJP, we will win elections: Mallaiya',
#  "PM Modi 'influencing' voters with Nepal visit: Congress",
#  'BJP using cops to hound Tharoor, says Congress',
#  'Punters predict no majority for BJP, Congress in Karnatka',
# ...

# %%
remove_none = []
for i in all_sentences_list:
  if i is not None:
    remove_none.append(i)

len(remove_none)
# Out:
# 6061

# %%
#df_split
lines = list()
for line in all_sentences_list:
  if line is not None:
    words = line.split()
    lines.append(words)


print(lines)
# Out:
# [['Discontent', 'over', 'cabinet', 'expansion', 'continues', 'in', 'Congress'], ['Lingayat', 'move', 'will', 'not', 'save', 'Congress', 'from', 'voters’', 'anger,', 'says', 'Prakash', 'Javadekar'], ['CPM,', 'Congress', 'join', 'hands', 'to', 'take', 'on', 'TMC', 'in', 'Bengal', 'bypolls'], ['Azad', 'seeking', 'votes', 'on', 'communal', 'lines,', 'says', 'BJP;', 'Congress', 'neta', 'denies', 'claim'], ['You', 'can', 'defeat', 'Rajas,', 'Maharajas', 'of', 'Congress:', 'Amit', 'Shah'], ['‘CPI', 'open', 'for', 'alliance', 'with', 'Congress', 'to', 'defeat', 'BJP’'], ['Congress', 'MLA', 'Aditi', 'Singh', 'denies', 'wedding', 'rumours', 'with', "'bro", 'Rahul', "Gandhi'"], ['2', 'arrested', 'for', 'murder', 'of', 'Congress', 'ex-MLA’s', 'cousin'], ['Congress', 'devises', 'strategy', 'to', 'keep', 'oust-CJI', 'move', '‘alive’'], ['Congress', 'MP', 'flays', 'govt', 'over', 'poor', 'law', 'and', 'order'], ['Congress', 'keeps', 'anti-PDA', 'pot', 'boiling,', 'wants', 'it', 'scrapped'], ['Congr
# ...

# %%
lines[0][3]

# %%
all_words_list_C = []

for i in lines:
    for j in i:
      all_words_list_C.append(j)

all_words_list_C
# Out:
# ['Discontent',
#  'over',
#  'cabinet',
#  'expansion',
#  'continues',
#  'in',
#  'Congress',
#  'Lingayat',
#  'move',
#  'will',
#  'not',
#  'save',
#  'Congress',
#  'from',
#  'voters’',
#  'anger,',
#  'says',
#  'Prakash',
#  'Javadekar',
#  'CPM,',
#  'Congress',
#  'join',
#  'hands',
#  'to',
#  'take',
#  'on',
#  'TMC',
#  'in',
#  'Bengal',
#  'bypolls',
#  'Azad',
#  'seeking',
#  'votes',
#  'on',
#  'communal',
#  'lines,',
#  'says',
#  'BJP;',
#  'Congress',
#  'neta',
#  'denies',
#  'claim',
#  'You',
#  'can',
#  'defeat',
#  'Rajas,',
#  'Maharajas',
#  'of',
#  'Congress:',
#  'Amit',
#  'Shah',
#  '‘CPI',
#  'open',
#  'for',
#  'alliance',
#  'with',
#  'Congress',
#  'to',
#  'defeat',
#  'BJP’',
#  'Congress',
#  'MLA',
#  'Aditi',
#  'Singh',
#  'denies',
#  'wedding',
#  'rumours',
#  'with',
#  "'bro",
#  'Rahul',
#  "Gandhi'",
#  '2',
#  'arrested',
#  'for',
#  'murder',
#  'of',
#  'Congress',
#  'ex-MLA’s',
#  'cousin',
#  'Congress',
# ...

# %%
all_words_list_C = [re.sub(r'[^A-Za-z0-9]+', '', x) for x in all_words_list_C]

all_words_list_C

lines2 = []

for word in all_words_list_C:
    if word != '':
        lines2.append(word)

# %%
freqdoctor = FreqDist()

for words in dfB:
    freqdoctor[words] += 1

freqdoctor
# Out:
# FreqDist({1: 1965,
#           2: 768,
#           3: 422,
#           4: 275,
#           5: 169,
#           6: 118,
#           7: 83,
#           8: 85,
#           9: 53,
#           10: 48,
#           11: 39,
#           12: 30,
#           13: 35,
#           14: 29,
#           15: 26,
#           16: 21,
#           17: 19,
#           18: 17,
#           19: 15,
#           20: 14,
#           21: 8,
#           22: 8,
#           23: 11,
#           24: 8,
#           25: 7,
#           26: 5,
#           27: 8,
#           28: 4,
#           29: 3,
#           30: 7,
#           31: 3,
#           32: 4,
#           33: 5,
#           34: 2,
#           35: 2,
#           36: 2,
#           37: 3,
#           38: 4,
#           39: 2,
#           40: 3,
#           41: 1,
#           42: 3,
#           43: 2,
#           44: 2,
#           45: 2,
#           46: 2,
#           47: 2,
#           48: 1,
#           49: 1,
#           51: 1,
#           52: 3,
# ...

# %%
lines2
# Out:
# ['Discontent',
#  'over',
#  'cabinet',
#  'expansion',
#  'continues',
#  'in',
#  'Congress',
#  'Lingayat',
#  'move',
#  'will',
#  'not',
#  'save',
#  'Congress',
#  'from',
#  'voters',
#  'anger',
#  'says',
#  'Prakash',
#  'Javadekar',
#  'CPM',
#  'Congress',
#  'join',
#  'hands',
#  'to',
#  'take',
#  'on',
#  'TMC',
#  'in',
#  'Bengal',
#  'bypolls',
#  'Azad',
#  'seeking',
#  'votes',
#  'on',
#  'communal',
#  'lines',
#  'says',
#  'BJP',
#  'Congress',
#  'neta',
#  'denies',
#  'claim',
#  'You',
#  'can',
#  'defeat',
#  'Rajas',
#  'Maharajas',
#  'of',
#  'Congress',
#  'Amit',
#  'Shah',
#  'CPI',
#  'open',
#  'for',
#  'alliance',
#  'with',
#  'Congress',
#  'to',
#  'defeat',
#  'BJP',
#  'Congress',
#  'MLA',
#  'Aditi',
#  'Singh',
#  'denies',
#  'wedding',
#  'rumours',
#  'with',
#  'bro',
#  'Rahul',
#  'Gandhi',
#  '2',
#  'arrested',
#  'for',
#  'murder',
#  'of',
#  'Congress',
#  'exMLAs',
#  'cousin',
#  'Congress',
#  'devises',
# ...

# %%
#This is stemming the words to their root
from nltk.stem.snowball import SnowballStemmer

# The Snowball Stemmer requires that you pass a language parameter
s_stemmer = SnowballStemmer(language='english')

stem = []
for word in lines2:
    stem.append(s_stemmer.stem(word))
    
stem
# Out:
# ['discont',
#  'over',
#  'cabinet',
#  'expans',
#  'continu',
#  'in',
#  'congress',
#  'lingayat',
#  'move',
#  'will',
#  'not',
#  'save',
#  'congress',
#  'from',
#  'voter',
#  'anger',
#  'say',
#  'prakash',
#  'javadekar',
#  'cpm',
#  'congress',
#  'join',
#  'hand',
#  'to',
#  'take',
#  'on',
#  'tmc',
#  'in',
#  'bengal',
#  'bypol',
#  'azad',
#  'seek',
#  'vote',
#  'on',
#  'communal',
#  'line',
#  'say',
#  'bjp',
#  'congress',
#  'neta',
#  'deni',
#  'claim',
#  'you',
#  'can',
#  'defeat',
#  'raja',
#  'maharaja',
#  'of',
#  'congress',
#  'amit',
#  'shah',
#  'cpi',
#  'open',
#  'for',
#  'allianc',
#  'with',
#  'congress',
#  'to',
#  'defeat',
#  'bjp',
#  'congress',
#  'mla',
#  'aditi',
#  'singh',
#  'deni',
#  'wed',
#  'rumour',
#  'with',
#  'bro',
#  'rahul',
#  'gandhi',
#  '2',
#  'arrest',
#  'for',
#  'murder',
#  'of',
#  'congress',
#  'exmla',
#  'cousin',
#  'congress',
#  'devis',
#  'strategi',
#  'to',
#  'keep',
# ...

# %%
# !python3 -m spacy download en_core_web_sm
# !pip3 install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ...
#      |████████████████████████████████| 12.0MB 257kB/s
# ...
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.2.0-cp36-none-any.whl size=12019126 sha256=886f04d6b094e3abcc7fec92778416c43af82387e90043d2ea5b48cd29e7c155
#   Stored in directory: /root/.cache/pip/wheels/48/5c/1c/15f9d02afc8221a668d2172446dd8467b20cdb9aef80a172a4
# Successfully built en-core-web-sm
# ...
#   Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# ...

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
stem2 = []

for word in stem:
    if word not in nlp.Defaults.stop_words:
        stem2.append(word)

stem2
# Out:
# ['discont',
#  'cabinet',
#  'expans',
#  'continu',
#  'congress',
#  'lingayat',
#  'save',
#  'congress',
#  'voter',
#  'anger',
#  'prakash',
#  'javadekar',
#  'cpm',
#  'congress',
#  'join',
#  'hand',
#  'tmc',
#  'bengal',
#  'bypol',
#  'azad',
#  'seek',
#  'vote',
#  'communal',
#  'line',
#  'bjp',
#  'congress',
#  'neta',
#  'deni',
#  'claim',
#  'defeat',
#  'raja',
#  'maharaja',
#  'congress',
#  'amit',
#  'shah',
#  'cpi',
#  'open',
#  'allianc',
#  'congress',
#  'defeat',
#  'bjp',
#  'congress',
#  'mla',
#  'aditi',
#  'singh',
#  'deni',
#  'wed',
#  'rumour',
#  'bro',
#  'rahul',
#  'gandhi',
#  '2',
#  'arrest',
#  'murder',
#  'congress',
#  'exmla',
#  'cousin',
#  'congress',
#  'devis',
#  'strategi',
#  'oustcji',
#  'aliv',
#  'congress',
#  'mp',
#  'flay',
#  'govt',
#  'poor',
#  'law',
#  'order',
#  'congress',
#  'antipda',
#  'pot',
#  'boil',
#  'want',
#  'scrap',
#  'congress',
#  'uniti',
#  'challeng',
#  'bjp',
#  'win',
#  'elect',
# ...

# %%
df = pd.DataFrame(stem2)

df = df[0].value_counts()

df
# Out:
# congress    3038
# gandhi       606
# rahul        596
# bjp          542
# elect        262
#             ...
# amitabh        1
# realti         1
# padhao         1
# univ           1
# worn           1
# Name: 0, Length: 4406, dtype: int64

# %%
from nltk.probability import FreqDist

freqdoctor = FreqDist()

for words in df:
    freqdoctor[words] += 1

freqdoctor
# Out:
# FreqDist({1: 1965,
#           2: 768,
#           3: 422,
#           4: 275,
#           5: 169,
#           6: 118,
#           7: 83,
#           8: 85,
#           9: 53,
#           10: 48,
#           11: 39,
#           12: 30,
#           13: 35,
#           14: 29,
#           15: 26,
#           16: 21,
#           17: 19,
#           18: 17,
#           19: 15,
#           20: 14,
#           21: 8,
#           22: 8,
#           23: 11,
#           24: 8,
#           25: 7,
#           26: 5,
#           27: 8,
#           28: 4,
#           29: 3,
#           30: 7,
#           31: 3,
#           32: 4,
#           33: 5,
#           34: 2,
#           35: 2,
#           36: 2,
#           37: 3,
#           38: 4,
#           39: 2,
#           40: 3,
#           41: 1,
#           42: 3,
#           43: 2,
#           44: 2,
#           45: 2,
#           46: 2,
#           47: 2,
#           48: 1,
#           49: 1,
#           51: 1,
#           52: 3,
# ...

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = df[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df.values, df.index, alpha=0.8)
plt.title('Top Words Overall: Congress & Rahul Gandhi')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()

# %%
import spacy
from spacy import displacy
from collections import Counter

# %%
def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(ent.text + ' - ' + ent.label_ + ' - ' + str(spacy.explain(ent.label_)))

# %%
def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(ent.text + ' - ' + ent.label_ + ' - ' + str(spacy.explain(ent.label_)))
str1 = " " 
stem2 = str1.join(lines2)

stem2 = nlp(stem2)

label = [(X.text, X.label_) for X in stem2.ents]

df6 = pd.DataFrame(label, columns = ['Word','Entity'])

df7 = df6.where(df6['Entity'] == 'ORG')

df7 = df7['Word'].value_counts()

df = df7[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df.values, df.index, alpha=1)
plt.title('Top Organizations Mentioned: Congress and Rahul Gandhi')
plt.ylabel('Word from Tweet', fontsize=14)
plt.xlabel('Count of Words', fontsize=14)
plt.show()

# %%
df = df7[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df.values, df.index, alpha=1)
plt.title('Top Organizations Mentioned: Congress and Rahul Gandhi')
plt.ylabel('Word from Tweet', fontsize=14)
plt.xlabel('Count of Words', fontsize=14)
plt.show()

# %%
str1 = " " 
stem2 = str1.join(lines2)

stem2 = nlp(stem2)

label = [(X.text, X.label_) for X in stem2.ents]

df10 = pd.DataFrame(label, columns = ['Word','Entity'])

df10 = df10.where(df10['Entity'] == 'PERSON')

df11 = df10['Word'].value_counts()

# %%
df = df11[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df.values, df.index, alpha=0.8)
plt.title('Top People Mentioned:')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()

# %%
from textblob import TextBlob

# %%
textbcongress = TextBlob(str(all_sentences_list))

# %%
import nltk
nltk.download('punkt')
  
nltk.download('brown')
textbcongress.noun_phrases
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# ...

# %%
nltk.download('averaged_perceptron_tagger')
textbcongress.tags
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('[', 'JJ'),
#  ("'Discontent", 'NN'),
#  ('over', 'IN'),
#  ('cabinet', 'JJ'),
#  ('expansion', 'NN'),
#  ('continues', 'VBZ'),
#  ('in', 'IN'),
#  ('Congress', 'NNP'),
#  ("'", 'POS'),
#  ('move', 'NN'),
#  ('will', 'MD'),
#  ('not', 'RB'),
#  ('save', 'VB'),
#  ('Congress', 'NNP'),
#  ('from', 'IN'),
#  ('voters', 'NNS'),
#  ('’', 'NNP'),
#  ('anger', 'NN'),
#  ('says', 'VBZ'),
#  ('Prakash', 'NNP'),
#  ('Javadekar', 'NNP'),
#  ("'", 'POS'),
#  ("'CPM", 'FW'),
#  ('Congress', 'NNP'),
#  ('join', 'VB'),
#  ('hands', 'NNS'),
#  ('to', 'TO'),
#  ('take', 'VB'),
#  ('on', 'IN'),
#  ('TMC', 'NNP'),
#  ('in', 'IN'),
#  ('Bengal', 'NNP'),
#  ('bypolls', 'NNS'),
#  ("'", 'POS'),
#  ("'Azad", 'CD'),
#  ('seeking', 'VBG'),
#  ('votes', 'NNS'),
#  ('on', 'IN'),
#  ('communal', 'JJ'),
#  ('lines', 'NNS'),
#  ('says', 'VBZ'),
# ...

# %%
textbcongress.sentiment
# Out:
# Sentiment(polarity=0.04405043867649213, subjectivity=0.41235583159038214)

# %%
textbcongress.words
# Out:
# WordList(["'Discontent", 'over', 'cabinet', 'expansion', 'continues', 'in', 'Congress', "'Lingayat", 'move', 'will', 'not', 'save', 'Congress', 'from', 'voters', '’', 'anger', 'says', 'Prakash', 'Javadekar', "'CPM", 'Congress', 'join', 'hands', 'to', 'take', 'on', 'TMC', 'in', 'Bengal', 'bypolls', "'Azad", 'seeking', 'votes', 'on', 'communal', 'lines', 'says', 'BJP', 'Congress', 'neta', 'denies', 'claim', "'You", 'can', 'defeat', 'Rajas', 'Maharajas', 'of', 'Congress', 'Amit', 'Shah', '‘', 'CPI', 'open', 'for', 'alliance', 'with', 'Congress', 'to', 'defeat', 'BJP', '’', 'Congress', 'MLA', 'Aditi', 'Singh', 'denies', 'wedding', 'rumours', 'with', "'bro", 'Rahul', 'Gandhi', "'2", 'arrested', 'for', 'murder', 'of', 'Congress', 'ex-MLA', '’', 's', 'cousin', "'Congress", 'devises', 'strategy', 'to', 'keep', 'oust-CJI', 'move', '‘', 'alive', '’', "'Congress", 'MP', 'flays', 'govt', 'over', 'poor', 'law', 'and', 'order', "'Congress", 'keeps', 'anti-PDA', 'pot', 'boiling', 'wants', 'it', 'sc
# ...

# %%
import pandas as pd
import numpy as np
#import twitterscraper as ts
from wordcloud import WordCloud
from textblob import TextBlob
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.rc('xtick', labelsize=5)
remove_none = []
for i in all_sentences_list:
  if i is not None:
    remove_none.append(i)

len(remove_none)
dfB_ = pd.DataFrame(remove_none)
# ## To create subjectivity (use to tell how subjective or opinionated the tweet is
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity
#
# ## To create polarity (use to tell how positive or negative the tweet is)
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# ## Create the Subjectivity and Polarity results columns in the df
dfB_["Subjectivity"] = dfB_[0].apply(getSubjectivity)
dfB_["Polarity"] = dfB_[0].apply(getPolarity)

def getAnalysis(score):
    if score < 0:
        return "Negative"
    elif score == 0:
        return "Neutral"
    else :
        return "Positive"
#
dfB_["Analysis"] = dfB_["Polarity"].apply(getAnalysis)

pheadlines = dfB_[dfB_.Analysis == "Positive"]
percentage_positive = pheadlines.shape[0] / df.shape[0]
print(percentage_positive)

nheadlines = dfB_[dfB_.Analysis == "Negative"]
percentage_negative = nheadlines.shape[0] / df.shape[0]
print(percentage_negative)
# Out:
# 84.5
# 52.7

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots()

positive = 25
negative = 18.15
neutral = 100 - 18.15 - 25

ax.broken_barh([(0, positive), (positive, positive+negative), (positive+negative, positive+negative+neutral)], [20, 1], facecolors=('greenyellow', 'coral', 'gainsboro'))
ax.set_ylim(1, 5)
ax.set_xlim(0, 100)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_yticks([15, 25])
ax.set_xticks([0, 25, 50, 75, 100])

ax.set_axisbelow(True) 

ax.set_yticklabels(['Q1'])
ax.grid(axis='x')
ax.text(positive-6, 19, "25%", fontsize=8)
ax.text((positive+negative)-6, 19, "18.15%", fontsize=8)
ax.text((positive+negative+neutral)+1, 19, "56.85%", fontsize=8)

fig.suptitle('Sentiment Analysis: BJP & Narendra Modi', fontsize=16)

leg1 = mpatches.Patch(color='greenyellow', label='Positive')
leg2 = mpatches.Patch(color='coral', label='Negative')
leg3 = mpatches.Patch(color='gainsboro', label='Neutral')
ax.legend(handles=[leg1, leg2, leg3], ncol=3)

plt.show()

# %%
font = {'weight' : 'bold',
        'size'   : 5}

plt.rc('font', **font)

# %%
dfC_ = pd.DataFrame(remove_none)

# %%
dfC_[0]
# Out:
# 0       Discontent over cabinet expansion continues in...
# 1       Lingayat move will not save Congress from vote...
# 2       CPM, Congress join hands to take on TMC in Ben...
# 3       Azad seeking votes on communal lines, says BJP...
# 4       You can defeat Rajas, Maharajas of Congress: A...
#                               ...
# 3705    Assembly election results: For Rahul Gandhi, a...
# 3706    Bihar Lok Sabha elections: Congress on back fo...
# 3707    Congress top guns fail to fire despite Sonia G...
# 3708    Congress top guns fail to fire despite Sonia G...
# 3709    Mizoram assembly election results highlights: ...
# Name: 0, Length: 3710, dtype: object

# %%
# ## To create subjectivity (use to tell how subjective or opinionated the tweet is
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity
#
# ## To create polarity (use to tell how positive or negative the tweet is)
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# ## Create the Subjectivity and Polarity results columns in the df
dfC_["Subjectivity"] = dfC_[0].apply(getSubjectivity)
dfC_["Polarity"] = dfC_[0].apply(getPolarity)

# %%
def getAnalysis(score):
    if score < 0:
        return "Negative"
    elif score == 0:
        return "Neutral"
    else :
        return "Positive"
#
dfC_["Analysis"] = dfC_["Polarity"].apply(getAnalysis)

# %%
pheadlines = dfC_[dfC_.Analysis == "Positive"]
percentage_positive = pheadlines.shape[0] / dfC_.shape[0]
print(percentage_positive)

nheadlines = dfC_[dfC_.Analysis == "Negative"]
percentage_negative = nheadlines.shape[0] / dfC_.shape[0]
print(percentage_negative)
# Out:
# 0.1347708894878706
# 0.09784366576819407

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots()

positive = 13.47
negative = 9.78
neutral = 76.75

ax.broken_barh([(0, positive), (positive, positive+negative), (positive+negative, positive+negative+neutral)], [20, 1], facecolors=('greenyellow', 'coral', 'gainsboro'))
ax.set_ylim(1, 5)
ax.set_xlim(0, 100)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_yticks([15, 25])
ax.set_xticks([0, 25, 50, 75, 100])

ax.set_axisbelow(True) 

ax.set_yticklabels(['Q1'])
ax.grid(axis='x')
ax.text(positive-6, 19, "13.47%", fontsize=8)
ax.text((positive+negative)-6, 19, "9.78%", fontsize=8)
ax.text((positive+negative+neutral)+1, 19, "76.75%", fontsize=8)

fig.suptitle('Sentiment Analysis: Congress and Rahul Gandhi', fontsize=16)

leg1 = mpatches.Patch(color='greenyellow', label='Positive')
leg2 = mpatches.Patch(color='coral', label='Negative')
leg3 = mpatches.Patch(color='gainsboro', label='Neutral')
ax.legend(handles=[leg1, leg2, leg3], ncol=3)

plt.show()

# %%
## Plotting and visualizing the counts
plt.title('Positive, Negative and Neutral Count')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
dfC_['Analysis'].value_counts().plot(kind = 'bar')
plt.show()

# %%
plt.figure(figsize=(8,6))
for i in range(0, dfC_.shape[0]): # in range from 0 to the no. of rows in our df
  plt.scatter(dfC_["Polarity"][i], dfC_["Subjectivity"][i], color='Blue')
plt.title('Congress & Rahul Gandhi')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.show()

# %%
plt.figure(figsize=(8,6))
for i in range(0, dfB_.shape[0]): # in range from 0 to the no. of rows in our df
  plt.scatter(dfB_["Polarity"][i], dfB_["Subjectivity"][i], color='Blue')
plt.title('BJP & Modi')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.show()
